# %% [markdown]
# ## Case study  - Uber Data Analysis
#
# You have the uber drive data for a driver which captures the differnet aspects of driving behavior. You are a part of the project where you need to grill this data and report the important findings from the grilling and drilling exercise. You also need to provide some useful insights about the trip behaviour of a Uber driver.
# Let us try to dive into the data with pandas and numpy by our side!
#
# #### Dataset -
# There are two datasets to be used here. The dataset contains-
#
# **Uberdrive.csv**
# - Trip_Id - Id for the trip
# - Start Date - the date and time of the start of the trip
# - End Date - the date and time of the end of the trip
# - Start Location - staring location of the trip
# - End Location  - location where the trip ended
# - Purpose of drive - Purpose of the trip (Business, Personal, Meals, Errands, Meetings, Customer Support etc.)
#
#
# **Uberdrive_Miles.csv**
# - Trip_Id - Id for the trip
# - Miles Driven  - Total miles driven between the start and the end of the trip
#
# #### Objective-
#
# The aim is to create a driver profile based on the below aspects on driving behavior.
# - Name and number of all the unique start and stop points
# - Popular start and stop points
# - Rides with same start and stop points
# - Starting point from which most miles have been driven
# - Start- stop pairs that are most travelled in terms of distance
# - busiest month in terms of number of drives and miles driven
# - busiest day of the week
# - peak hours
# - most frequent trip category
# - most frequent trip purpose
# - miles driven per category and purpose
# - percent composition of business miles vs personal miles
# - time spent per category and purpose
#
# ----------------------
#  #### Concepts To cover
# ----------------------
# - 1. <a href = #link1>Overview of the data at hand</a>
# - 2. <a href = #link3>Filtering Data</a>
# - 3. <a href = #link2>Data profiling and the functions offered by pandas for understanding the data</a>
# - 4. <a href = #link4>DateTime operations</a>

# %%
# Import the libraries 
import pandas as pd
import numpy as np

# %% [markdown]
# ### <a id = "link1"></a>Overview of the data

# %%
# Read the Data
df= pd.read_csv('uberdrive.csv')

# %%
# View first 3 rows of data 
df.head(3)
# Out:
#    Trip_Id       START_DATE*         END_DATE* CATEGORY*       START*  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
#
#          STOP*         PURPOSE*
# 0  Fort Pierce   Meal/Entertain
# 1  Fort Pierce              NaN
# 2  Fort Pierce  Errand/Supplies

# %%
df_miles=pd.read_csv('UberDrive_Miles.csv')

# %%
df_miles.head(3)
# Out:
#    Trip_Id  MILES*
# 0        1     5.1
# 1        2     5.0
# 2        3     4.8

# %%
# understand shape and size of data from Uberdrive
df.shape
# Out:
# (1155, 7)

# %%
df.size
# Out:
# 8085

# %%
# check info about data (includes column names, the number of non-null values in it, and data-type for each column.)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Trip_Id      1155 non-null   int64
#  1   START_DATE*  1155 non-null   object
#  2   END_DATE*    1155 non-null   object
#  3   CATEGORY*    1155 non-null   object
#  4   START*       1155 non-null   object
#  5   STOP*        1155 non-null   object
#  6   PURPOSE*     653 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 63.3+ KB

# %%
df_miles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1155 entries, 0 to 1154
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Trip_Id  1155 non-null   int64
#  1   MILES*   1155 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 18.2 KB

# %%
df_miles.shape
# Out:
# (1155, 2)

# %% [markdown]
# 1. PURPOSE column has lots of missing values.
# 2. We can update column names to remove asterisk sign, lets rename the columns.

# %% [markdown]
# ### Renaming columns

# %%
# Approach 1
# Replace the * character from all the  columns
df.columns= df.columns.str.replace('*', '')
# Out:
# <ipython-input-11-ea562ea6473a>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   df.columns= df.columns.str.replace('*', '')

# %%
df.columns #asterisk is removed
# Out:
# Index(['Trip_Id', 'START_DATE', 'END_DATE', 'CATEGORY', 'START', 'STOP',
#        'PURPOSE'],
#       dtype='object')

# %%
# Approach 2
#
# You can also rename the specific column names 
df_miles=df_miles.rename(columns={'MILES*':'MILES'})

# %%
df_miles.columns
# Out:
# Index(['Trip_Id', 'MILES'], dtype='object')

# %% [markdown]
# **The column names were updated.**

# %% [markdown]
# ### <a id = "link3"></a>Filtering dataframes
# #### Using null values

# %%
#to check if column PURPOSE have null values or not.
df['PURPOSE'].isnull()
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1150    False
# 1151    False
# 1152    False
# 1153    False
# 1154    False
# Name: PURPOSE, Length: 1155, dtype: bool

# %%
# shows the top 5 entries where PURPOSE is null
df[df['PURPOSE'].isnull()].head(5)             #isna will give same results
# Out:
#     Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 1         2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 32       33    1/19/2016 9:09    1/19/2016 9:23  Business  Whitebridge
# 85       86  02-09-2016 10:54  02-09-2016 11:07  Personal  Whitebridge
# 86       87  02-09-2016 11:43  02-09-2016 11:50  Personal   Northwoods
# 87       88  02-09-2016 13:36  02-09-2016 13:52  Personal   Tanglewood
#
#                    STOP PURPOSE
# 1           Fort Pierce     NaN
# 32  Lake Wellingborough     NaN
# 85           Northwoods     NaN
# 86           Tanglewood     NaN
# 87              Preston     NaN

# %% [markdown]
# #### Filtering out records based on conditions

# %%
# Conditions within dataframe 
#select top 10 entries where miles>30
df_miles[df_miles['MILES']>30].head(10)
# Out:
#      Trip_Id  MILES
# 4          5   63.7
# 36        37   40.2
# 108      109   43.7
# 232      233  136.0
# 233      234   30.2
# 245      246   35.1
# 246      247   36.5
# 251      252   57.0
# 268      269  144.0
# 269      270  310.3

# %% [markdown]
# ## <a id = "link2"></a>In a bid to create the driver profile, lets explore the data parameter wise -
#
# - 1.Destination - (starting and stopping)
#
# - 2.Time - (hour of the day, day of week, month of year)
#
# - 3.Grouping two parameters to get more insights
#
# - 4.Category and Purpose

# %% [markdown]
# ## 1. Destination
# ### Understanding  the start and stop points
# ###### Through the feature, we will try to understand the below points of the driver profile.
# - Name and number of all the unique start and stop points
# - Popular start and stop points
# - Rides with same start and stop points
# - Starting point from which most miles have been driven
# - Start- stop pairs that are most travelled in terms of distance
#
# **Let us handle these one by one**

# %% [markdown]
# **1. Name and Number of all unique start and stop points**

# %%
# Get the unique starting point, unique destination
# names of unique start points
df.START.unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Cary', 'Jamaica', 'New York',
#        'Elmhurst', 'Midtown', 'East Harlem', 'Flatiron District',
#        'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Downtown', 'Gulfton', 'Houston', 'Eagan Park',
#        'Morrisville', 'Durham', 'Farmington Woods', 'Whitebridge',
#        'Lake Wellingborough', 'Fayetteville Street', 'Raleigh',
#        'Hazelwood', 'Fairmont', 'Meredith Townes', 'Apex', 'Chapel Hill',
#        'Northwoods', 'Edgehill Farms', 'Tanglewood', 'Preston',
#        'Eastgate', 'East Elmhurst', 'Jackson Heights', 'Long Island City',
#        'Katunayaka', 'Unknown Location', 'Colombo', 'Nugegoda',
#        'Islamabad', 'R?walpindi', 'Noorpur Shahan', 'Heritage Pines',
#        'Westpark Place', 'Waverly Place', 'Wayne Ridge', 'Weston',
#        'East Austin', 'West University', 'South Congress', 'The Drag',
#        'Congress Ave District', 'Red River District', 'Georgian Acres',
#        'North Austin', 'Coxville', 'Convention Center District', 'Austin',
#        'Katy', 'Sharpstown', 'Sugar Land', 'Galveston', 'Port Bolivar',
#        'Washington Avenue', 'Briar Meadow', 'Latta', 'Jacksonville',
#        'Couples Glen', 'Kissimmee', 'Lake Reams', 'Orlando',
#        'Sand Lake Commons', 'Sky Lake', 'Daytona Beach', 'Ridgeland',
#        'Florence', 'Meredith', 'Holly Springs', 'Chessington', 'Burtrose',
#        'Parkway', 'Mcvan', 'Capitol One', 'University District',
#        'Seattle', 'Redmond', 'Bellevue', 'San Francisco', 'Palo Alto',
#        'Sunnyvale', 'Newark', 'Menlo Park', 'Old City', 'Savon Height',
#        'Kilarney Woods', 'Townes at Everett Crossing', 'Huntington Woods',
#        'Seaport', 'Medical Centre', 'Rose Hill', 'Soho', 'Tribeca',
#        'Financial District', 'Oakland', 'Emeryville', 'Berkeley',
#        'Kenner', 'CBD', 'Lower Garden District', 'Lakeview', 'Storyville',
#        'New Orleans', 'Metairie', 'Chalmette', 'Arabi',
#        'Pontchartrain Shores', 'Marigny', 'Covington', 'Mandeville',
#        'Jamestown Court', 'Summerwinds', 'Parkwood',
#        'Pontchartrain Beach', 'St Thomas', 'Banner Elk', 'Elk Park',
#        'Newland', 'Boone', 'Stonewater', 'Lexington Park at Amberly',
#        'Arlington Park at Amberly', 'Arlington', 'Kalorama Triangle',
#        'K Street', 'West End', 'Connecticut Avenue', 'Columbia Heights',
#        'Washington', 'Wake Forest', 'Lahore', 'Karachi', 'SOMISSPO',
#        'West Berkeley', 'North Berkeley Hills', 'San Jose', 'Eagle Rock',
#        'Winston Salem', 'Asheville', 'Topton', 'Hayesville',
#        'Bryson City', 'Almond', 'Mebane', 'Agnew', 'Cory', 'Renaissance',
#        'Santa Clara', 'NOMA', 'Sunnyside', 'Ingleside', 'Central',
#        'Tenderloin', 'College Avenue', 'South', 'Southside',
#        'South Berkeley', 'Mountain View', 'El Cerrito', 'Krendle Woods',
#        'Wake Co.', 'Fuquay-Varina', 'Rawalpindi', 'Kar?chi', 'Katunayake',
#        'Gampaha'], dtype=object)

# %%
df.START.nunique()      #  can use the nunique function
# Out:
# 177

# %%
# Get the names of stopping destinations, unique destinations
# Names of unique stopping points
df.STOP.unique()
# Out:
# array(['Fort Pierce', 'West Palm Beach', 'Palm Beach', 'Cary',
#        'Morrisville', 'New York', 'Queens', 'East Harlem', 'NoMad',
#        'Midtown', 'Midtown East', 'Hudson Square', 'Lower Manhattan',
#        "Hell's Kitchen", 'Queens County', 'Gulfton', 'Downtown',
#        'Houston', 'Jamestown Court', 'Durham', 'Whitebridge',
#        'Lake Wellingborough', 'Raleigh', 'Umstead', 'Hazelwood',
#        'Westpark Place', 'Meredith Townes', 'Leesville Hollow', 'Apex',
#        'Chapel Hill', 'Williamsburg Manor', 'Macgregor Downs',
#        'Edgehill Farms', 'Northwoods', 'Tanglewood', 'Preston',
#        'Walnut Terrace', 'Jackson Heights', 'East Elmhurst',
#        'Midtown West', 'Long Island City', 'Jamaica', 'Unknown Location',
#        'Colombo', 'Nugegoda', 'Katunayaka', 'Islamabad', 'R?walpindi',
#        'Noorpur Shahan', 'Heritage Pines', 'Waverly Place', 'Wayne Ridge',
#        'Depot Historic District', 'Weston', 'West University',
#        'South Congress', 'Arts District', 'Congress Ave District',
#        'Red River District', 'The Drag', 'Convention Center District',
#        'North Austin', 'Coxville', 'Katy', 'Alief', 'Sharpstown',
#        'Sugar Land', 'Galveston', 'Port Bolivar', 'Washington Avenue',
#        'Briar Meadow', 'Greater Greenspoint', 'Latta', 'Jacksonville',
#        'Kissimmee', 'Isles of Buena Vista', 'Orlando', 'Lake Reams',
#        'Vista East', 'Sky Lake', 'Sand Lake Commons', 'Daytona Beach',
#        'Ridgeland', 'Florence', 'Cedar Hill', 'Holly Springs',
#        'Harden Place', 'Chessington', 'Burtrose', 'Parkway',
#        'Capitol One', 'University District', 'Redmond', 'Bellevue',
#        'Seattle', 'Mcvan', 'Palo Alto', 'Sunnyvale', 'Newark',
#        'Menlo Park', 'San Francisco', 'Parkway Museums', 'Hog Island',
#        'Savon Height', 'Kildaire Farms', 'Kilarney Woods',
#        'Gramercy-Flatiron', 'Tudor City', 'Soho', 'Tribeca',
#        'Financial District', 'Kips Bay', 'Emeryville', 'Berkeley',
#        'Oakland', 'Bay Farm Island', 'New Orleans',
#        'Lower Garden District', 'Lakeview', 'Storyville',
#        'Faubourg Marigny', 'Metairie', 'Kenner', 'Bywater', 'Chalmette',
#        'Arabi', 'Pontchartrain Shores', 'Marigny', 'Covington',
#        'Mandeville', 'Summerwinds', 'Parkwood', 'Pontchartrain Beach',
#        'CBD', 'St Thomas', 'Banner Elk', 'Elk Park', 'Newland', 'Boone',
#        'Stonewater', 'Lexington Park at Amberly',
#        'Arlington Park at Amberly', 'Washington', 'K Street',
#        'Kalorama Triangle', 'Northwest Rectangle', 'Columbia Heights',
#        'Arlington', 'Farmington Woods', 'Wake Forest', 'Lahore',
#        'Karachi', 'French Quarter', 'North Berkeley Hills', 'Southside',
#        'San Jose', 'Eagle Rock', 'Huntington Woods', 'Winston Salem',
#        'Asheville', 'Topton', 'Hayesville', 'Bryson City', 'Almond',
#        'Mebane', 'Santa Clara', 'Cory', 'Agnew', 'Renaissance',
#        'West Berkeley', 'Central', 'Sunnyside', 'Ingleside',
#        'Potrero Flats', 'SOMISSPO', 'Tenderloin', 'College Avenue',
#        'South', 'Southwest Berkeley', 'South Berkeley', 'Mountain View',
#        'El Cerrito', 'Wake Co.', 'Fuquay-Varina', 'Rawalpindi', 'Kar?chi',
#        'Gampaha', 'Ilukwatta'], dtype=object)

# %%
df.STOP.nunique()      # count of unique stopping points
# Out:
# 188

# %% [markdown]
# **2a. Identify popular start points - top 10**

# %%
df['START'].value_counts().head(10)
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Durham               37
# Lahore               36
# Raleigh              28
# Kar?chi              27
# Apex                 17
# Name: START, dtype: int64

# %%
df.START.value_counts().head(10)        #can write column name like this too
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Durham               37
# Lahore               36
# Raleigh              28
# Kar?chi              27
# Apex                 17
# Name: START, dtype: int64

# %% [markdown]
# **2b. Identify popular stop destinations - top 10**

# %%
df['STOP'].value_counts().head(10)
# Out:
# Cary                203
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
# Lahore               36
# Durham               36
# Raleigh              29
# Kar?chi              26
# Apex                 17
# Name: STOP, dtype: int64

# %% [markdown]
# **3.  Are there cases where the start and the stop location are the same  ?**

# %%
#df[df['START'].isin(df['STOP'])]
#df.isin({START:STOP})
df[df['START']==df['STOP']]
# Out:
#       Trip_Id        START_DATE          END_DATE  CATEGORY             START  \
# 0           1  01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1           2  01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2           3  01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3           4  01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 5           6  01-06-2016 17:15  01-06-2016 17:19  Business   West Palm Beach
# ...       ...               ...               ...       ...               ...
# 1147     1148  12/30/2016 15:41  12/30/2016 16:03  Business           Kar?chi
# 1148     1149  12/30/2016 16:45  12/30/2016 17:08  Business           Kar?chi
# 1149     1150  12/30/2016 23:06  12/30/2016 23:10  Business           Kar?chi
# 1150     1151   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1152     1153  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
#
#                   STOP          PURPOSE
# 0          Fort Pierce   Meal/Entertain
# 1          Fort Pierce              NaN
# 2          Fort Pierce  Errand/Supplies
# 3          Fort Pierce          Meeting
# 5      West Palm Beach   Meal/Entertain
# ...                ...              ...
# 1147           Kar?chi  Errand/Supplies
# 1148           Kar?chi          Meeting
# 1149           Kar?chi   Customer Visit
# 1150           Kar?chi          Meeting
# 1152  Unknown Location          Meeting
#
# [288 rows x 7 columns]

# %%
df[df['START']==df['STOP']].shape
# Out:
# (288, 7)

# %%
df[df['START']==df['STOP']].head(5)
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY            START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 5        6  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
#
#               STOP          PURPOSE
# 0      Fort Pierce   Meal/Entertain
# 1      Fort Pierce              NaN
# 2      Fort Pierce  Errand/Supplies
# 3      Fort Pierce          Meeting
# 5  West Palm Beach   Meal/Entertain

# %% [markdown]
# **288 trips have the same start and stop points**

# %% [markdown]
# **4.Starting point from which the most miles have been driven**
#
# **In order to use the miles feature, let us now merge the two dataframes so that the all the information is in one dataframe.**
# - using merge

# %%
new_df=pd.merge(df,df_miles,how='left',on='Trip_Id')                  #left join is most appropriate
new_df                                     #we don't want to compromise with the bigger dataframe which has more information)
# Out:
#       Trip_Id        START_DATE          END_DATE  CATEGORY             START  \
# 0           1  01-01-2016 21:11  01-01-2016 21:17  Business       Fort Pierce
# 1           2  01-02-2016 01:25  01-02-2016 01:37  Business       Fort Pierce
# 2           3  01-02-2016 20:25  01-02-2016 20:38  Business       Fort Pierce
# 3           4  01-05-2016 17:31  01-05-2016 17:45  Business       Fort Pierce
# 4           5  01-06-2016 14:42  01-06-2016 15:49  Business       Fort Pierce
# ...       ...               ...               ...       ...               ...
# 1150     1151   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151     1152  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152     1153  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153     1154  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154     1155  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                   STOP          PURPOSE  MILES
# 0          Fort Pierce   Meal/Entertain    5.1
# 1          Fort Pierce              NaN    5.0
# 2          Fort Pierce  Errand/Supplies    4.8
# 3          Fort Pierce          Meeting    4.7
# 4      West Palm Beach   Customer Visit   63.7
# ...                ...              ...    ...
# 1150           Kar?chi          Meeting    0.7
# 1151  Unknown Location   Temporary Site    3.9
# 1152  Unknown Location          Meeting   16.2
# 1153           Gampaha   Temporary Site    6.4
# 1154         Ilukwatta   Temporary Site   48.2
#
# [1155 rows x 8 columns]

# %%
new_df.shape
# Out:
# (1155, 8)

# %% [markdown]
# **Let's now use groupby function to find the starting point from which the most miles have been driven**

# %%
new_df.groupby(['START'])['MILES'].sum().sort_values(ascending = False ).head(10)
# Out:
# START
# Unknown Location    1976.5
# Cary                1791.3
# Morrisville          671.7
# Raleigh              433.0
# Islamabad            401.2
# Durham               384.4
# Jacksonville         375.2
# Latta                310.3
# Asheville            287.7
# Whitebridge          273.4
# Name: MILES, dtype: float64

# %% [markdown]
# most miles have been driven from Cary

# %% [markdown]
# **5. Find the top10 start stop pair that have the most miles covered between them ever.**

# %%
# Let us drop the unknown locations
df1=new_df.drop(new_df.loc[new_df['START']=='Unknown Location'].index) 
df1 # Makes a new dataframe, which don't have "Unknown Location" as starting point
# Out:
#       Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0           1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1           2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2           3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3           4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4           5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
# ...       ...               ...               ...       ...          ...
# 1149     1150  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150     1151   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1151     1152  12/31/2016 13:24  12/31/2016 13:42  Business      Kar?chi
# 1153     1154  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154     1155  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
#
#                   STOP          PURPOSE  MILES
# 0          Fort Pierce   Meal/Entertain    5.1
# 1          Fort Pierce              NaN    5.0
# 2          Fort Pierce  Errand/Supplies    4.8
# 3          Fort Pierce          Meeting    4.7
# 4      West Palm Beach   Customer Visit   63.7
# ...                ...              ...    ...
# 1149           Kar?chi   Customer Visit    0.8
# 1150           Kar?chi          Meeting    0.7
# 1151  Unknown Location   Temporary Site    3.9
# 1153           Gampaha   Temporary Site    6.4
# 1154         Ilukwatta   Temporary Site   48.2
#
# [1007 rows x 8 columns]

# %%
df1.shape
# Out:
# (1007, 8)

# %%
#alternate approach
#df2 = df[df['START'] != 'Unknown Location']
#df2 = df2[df2['STOP'] != 'Unknown Location']# Further updates the df2 dataframe, by removing "Unknown Location" as stopping point

# %%
df2=df1.drop(df1.loc[df['STOP']=='Unknown Location'].index)  #now removing 'unknown location from stopping point'
df2
# Out:
#       Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0           1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1           2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2           3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3           4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4           5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
# ...       ...               ...               ...       ...          ...
# 1148     1149  12/30/2016 16:45  12/30/2016 17:08  Business      Kar?chi
# 1149     1150  12/30/2016 23:06  12/30/2016 23:10  Business      Kar?chi
# 1150     1151   12/31/2016 1:07   12/31/2016 1:14  Business      Kar?chi
# 1153     1154  12/31/2016 21:32  12/31/2016 21:50  Business   Katunayake
# 1154     1155  12/31/2016 22:08  12/31/2016 23:51  Business      Gampaha
#
#                  STOP          PURPOSE  MILES
# 0         Fort Pierce   Meal/Entertain    5.1
# 1         Fort Pierce              NaN    5.0
# 2         Fort Pierce  Errand/Supplies    4.8
# 3         Fort Pierce          Meeting    4.7
# 4     West Palm Beach   Customer Visit   63.7
# ...               ...              ...    ...
# 1148          Kar?chi          Meeting    4.6
# 1149          Kar?chi   Customer Visit    0.8
# 1150          Kar?chi          Meeting    0.7
# 1153          Gampaha   Temporary Site    6.4
# 1154        Ilukwatta   Temporary Site   48.2
#
# [944 rows x 8 columns]

# %%
# top 10 most miles covered between a start stop pair
df2.groupby(['START','STOP'])['MILES'].sum().sort_values(ascending=False).head(10)
# Out:
# START         STOP
# Morrisville   Cary            395.7
# Cary          Durham          390.0
#               Morrisville     380.0
# Raleigh       Cary            365.7
# Cary          Raleigh         336.5
# Durham        Cary            334.4
# Latta         Jacksonville    310.3
# Cary          Cary            255.9
# Jacksonville  Kissimmee       201.0
# Asheville     Mebane          195.9
# Name: MILES, dtype: float64

# %%
S_S=df2.groupby(['START','STOP'])['MILES'].sum().sort_values(ascending=False).head(10) 
S_S=S_S.reset_index()      #flatten the dataframe        
S_S['Start-Stop']=S_S['START'] + '-' + S_S['STOP']    #new dataframe with start stop pair column
S_S
# Out:
#           START          STOP  MILES              Start-Stop
# 0   Morrisville          Cary  395.7        Morrisville-Cary
# 1          Cary        Durham  390.0             Cary-Durham
# 2          Cary   Morrisville  380.0        Cary-Morrisville
# 3       Raleigh          Cary  365.7            Raleigh-Cary
# 4          Cary       Raleigh  336.5            Cary-Raleigh
# 5        Durham          Cary  334.4             Durham-Cary
# 6         Latta  Jacksonville  310.3      Latta-Jacksonville
# 7          Cary          Cary  255.9               Cary-Cary
# 8  Jacksonville     Kissimmee  201.0  Jacksonville-Kissimmee
# 9     Asheville        Mebane  195.9        Asheville-Mebane

# %% [markdown]
# **The most popular start to destination pair is Morrisville-Cary**

# %% [markdown]
# <a id = "link4"></a>
# ## 2. Start Date - End Date
# ### Manipulating date & time objects
# #### Lets explore the variables using the below points-
# - busiest month in terms of number of drives and miles driven
# - busiest day of the week and preferred start hour
# - peak hours
#
# We will create more features for the trip data to be able to cater to above profile mappings

# %%
new_df.head(3)
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
#
#           STOP          PURPOSE  MILES
# 0  Fort Pierce   Meal/Entertain    5.1
# 1  Fort Pierce              NaN    5.0
# 2  Fort Pierce  Errand/Supplies    4.8

# %%
new_df.dtypes
# Out:
# Trip_Id         int64
# START_DATE     object
# END_DATE       object
# CATEGORY       object
# START          object
# STOP           object
# PURPOSE        object
# MILES         float64
# dtype: object

# %%
# Create columns by converting the start and end date into a datetime format
# we can also over write the same column - but for the sake of understanding the difference in formats, we create new columns
new_df['start_dt']=pd.to_datetime(new_df['START_DATE'])
new_df['end_dt']=pd.to_datetime(new_df['END_DATE'])

# %%
new_df.dtypes   # See how the dtype is different
# Out:
# Trip_Id                int64
# START_DATE            object
# END_DATE              object
# CATEGORY              object
# START                 object
# STOP                  object
# PURPOSE               object
# MILES                float64
# start_dt      datetime64[ns]
# end_dt        datetime64[ns]
# dtype: object

# %%
new_df.head(5)           # Print first 5 rows of data.
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt
# 0 2016-01-01 21:17:00
# 1 2016-01-02 01:37:00
# 2 2016-01-02 20:38:00
# 3 2016-01-05 17:45:00
# 4 2016-01-06 15:49:00

# %%
import datetime

# %%
datetime.datetime.now()     #first check today's date
# Out:
# datetime.datetime(2021, 9, 30, 11, 53, 54, 320325)

# %%
# Create more columns by using the inbuilt functionalities of datetime module  
new_df['start_day']=new_df['start_dt'].dt.day                 # Days encoded as 0-6  ( monday =0, Tue =1 .... )
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day
# 0 2016-01-01 21:17:00          1
# 1 2016-01-02 01:37:00          2
# 2 2016-01-02 20:38:00          2
# 3 2016-01-05 17:45:00          5
# 4 2016-01-06 15:49:00          6

# %%
new_df['start_hour']=new_df['start_dt'].dt.hour
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour
# 0 2016-01-01 21:17:00          1          21
# 1 2016-01-02 01:37:00          2           1
# 2 2016-01-02 20:38:00          2          20
# 3 2016-01-05 17:45:00          5          17
# 4 2016-01-06 15:49:00          6          14

# %%
new_df['start_month']=new_df['start_dt'].dt.month
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month
# 0 2016-01-01 21:17:00          1          21            1
# 1 2016-01-02 01:37:00          2           1            1
# 2 2016-01-02 20:38:00          2          20            1
# 3 2016-01-05 17:45:00          5          17            1
# 4 2016-01-06 15:49:00          6          14            1

# %%
new_df['d_of_week']=new_df['start_dt'].dt.weekday
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2

# %%
new_df['weekday']=new_df['start_dt'].dt.day_name()
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
#
#      weekday
# 0     Friday
# 1   Saturday
# 2   Saturday
# 3    Tuesday
# 4  Wednesday

# %%
new_df['cal_month']=new_df['start_dt'].dt.month_name()
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
#
#      weekday cal_month
# 0     Friday   January
# 1   Saturday   January
# 2   Saturday   January
# 3    Tuesday   January
# 4  Wednesday   January

# %% [markdown]
# **Now let us answer the questions below.**
# <br>
# <br>
# **1. Busiest month in terms of number of drives and miles driven**

# %%
#groupby calender months and count the number of drives
new_df.groupby(['cal_month'])['Trip_Id'].count().sort_values(ascending=False).head(5)
# Out:
# cal_month
# December    146
# August      133
# November    122
# February    115
# March       113
# Name: Trip_Id, dtype: int64

# %% [markdown]
# **December appears to be the busiest month in terms of number of drives**

# %%
#groupby calender months and calculate total miles driven
new_df.groupby(['cal_month'])['MILES'].sum().sort_values(ascending=False).head(5)
# Out:
# cal_month
# October    1810.0
# March      1693.9
# August     1335.5
# July       1224.6
# April      1113.0
# Name: MILES, dtype: float64

# %% [markdown]
# **October appears to be the busiest month in terms of miles driven**

# %% [markdown]
# **2. Busiest day in terms of number of rides**

# %%
# Which day did the driver get most drives? 
new_df.groupby(['weekday'])['Trip_Id'].size().sort_values(ascending=False)         
 
#note that .count() could also have been used. However, .size() makes it look more clean.
# Out:
# weekday
# Friday       206
# Tuesday      176
# Monday       174
# Thursday     154
# Saturday     150
# Sunday       148
# Wednesday    147
# Name: Trip_Id, dtype: int64

# %% [markdown]
# **friday is the busiest day in terms of drives.**

# %% [markdown]
# **3. Peak hours ?**

# %%
new_df.groupby(['start_hour'])['Trip_Id'].count().sort_values(ascending=False).head() # The number of trips started for each hour.
# Out:
# start_hour
# 15    98
# 17    95
# 18    94
# 13    94
# 14    89
# Name: Trip_Id, dtype: int64

# %% [markdown]
# **Looks like the peak hours seem to be between 3PM - 6PM**

# %% [markdown]
# #### Figure out the trips that are starting and ending at the same time (0 minutes elapsed).
# <br>

# %%
new_df['diff'] = (new_df['end_dt'] - new_df['start_dt'])
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
#
#      weekday cal_month            diff
# 0     Friday   January 0 days 00:06:00
# 1   Saturday   January 0 days 00:12:00
# 2   Saturday   January 0 days 00:13:00
# 3    Tuesday   January 0 days 00:14:00
# 4  Wednesday   January 0 days 01:07:00

# %%
# Out:
# Trip_Id                  int64
# START_DATE              object
# END_DATE                object
# CATEGORY                object
# START                   object
# STOP                    object
# PURPOSE                 object
# MILES                  float64
# start_dt        datetime64[ns]
# end_dt          datetime64[ns]
# start_day                int64
# start_hour               int64
# start_month              int64
# d_of_week                int64
# weekday                 object
# cal_month               object
# diff           timedelta64[ns]
# dtype: object

# %%
new_df[new_df['diff']=='0 days 00:00:00']   #to check 0 minutes ellapsed
# Out:
#      Trip_Id        START_DATE          END_DATE  CATEGORY             START  \
# 751      752  09-06-2016 17:49  09-06-2016 17:49  Business  Unknown Location
# 761      762    9/16/2016 7:08    9/16/2016 7:08  Business  Unknown Location
# 798      799  10-08-2016 15:03  10-08-2016 15:03  Business           Karachi
# 807      808  10/13/2016 13:02  10/13/2016 13:02  Business         Islamabad
#
#                  STOP PURPOSE  MILES            start_dt              end_dt  \
# 751  Unknown Location     NaN   69.1 2016-09-06 17:49:00 2016-09-06 17:49:00
# 761  Unknown Location     NaN    1.6 2016-09-16 07:08:00 2016-09-16 07:08:00
# 798           Karachi     NaN    3.6 2016-10-08 15:03:00 2016-10-08 15:03:00
# 807         Islamabad     NaN    0.7 2016-10-13 13:02:00 2016-10-13 13:02:00
#
#      start_day  start_hour  start_month  d_of_week   weekday  cal_month   diff
# 751          6          17            9          1   Tuesday  September 0 days
# 761         16           7            9          4    Friday  September 0 days
# 798          8          15           10          5  Saturday    October 0 days
# 807         13          13           10          3  Thursday    October 0 days

# %% [markdown]
# **following are the trips that are starting and ending at the same time.**

# %%
new_df.dtypes   #to check the datatype of new coumn
# Out:
# Trip_Id                  int64
# START_DATE              object
# END_DATE                object
# CATEGORY                object
# START                   object
# STOP                    object
# PURPOSE                 object
# MILES                  float64
# start_dt        datetime64[ns]
# end_dt          datetime64[ns]
# start_day                int64
# start_hour               int64
# start_month              int64
# d_of_week                int64
# weekday                 object
# cal_month               object
# diff           timedelta64[ns]
# dtype: object

# %% [markdown]
# This creates a timedelta datatype

# %% [markdown]
# Find the date time units in  https://docs.scipy.org/doc/numpy/reference/arrays.datetime.html
#
# search for 'Datetime Units'

# %% [markdown]
# #### For practice- Exploring existing features to create new ones - Speed
# - Open for all of you to explore and figure out what all can be understood and derived from this feature

# %%
datetime.timedelta(seconds=24*60*60).total_seconds()     #understanding the use of total_seconds
# Out:
# 86400.0

# %%
new_df[:]['diff']/np.timedelta64(1,'s')      #it converts timedelta to float datatype for further calculation
# Out:
# 0        360.0
# 1        720.0
# 2        780.0
# 3        840.0
# 4       4020.0
#          ...
# 1150     420.0
# 1151    1080.0
# 1152    2100.0
# 1153    1080.0
# 1154    6180.0
# Name: diff, Length: 1155, dtype: float64

# %%
new_df['seconds']=new_df[:]['diff']/np.timedelta64(1,'s')         #inserting it as a new column
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
#
#      weekday cal_month            diff  seconds
# 0     Friday   January 0 days 00:06:00    360.0
# 1   Saturday   January 0 days 00:12:00    720.0
# 2   Saturday   January 0 days 00:13:00    780.0
# 3    Tuesday   January 0 days 00:14:00    840.0
# 4  Wednesday   January 0 days 01:07:00   4020.0

# %%
new_df.dtypes
# Out:
# Trip_Id                  int64
# START_DATE              object
# END_DATE                object
# CATEGORY                object
# START                   object
# STOP                    object
# PURPOSE                 object
# MILES                  float64
# start_dt        datetime64[ns]
# end_dt          datetime64[ns]
# start_day                int64
# start_hour               int64
# start_month              int64
# d_of_week                int64
# weekday                 object
# cal_month               object
# diff           timedelta64[ns]
# seconds                float64
# dtype: object

# %%
new_df['speed']=new_df['MILES']/new_df['seconds']          #now, making a new column of speed 
new_df.head()
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY        START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business  Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business  Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business  Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business  Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business  Fort Pierce
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
#
#      weekday cal_month            diff  seconds     speed
# 0     Friday   January 0 days 00:06:00    360.0  0.014167
# 1   Saturday   January 0 days 00:12:00    720.0  0.006944
# 2   Saturday   January 0 days 00:13:00    780.0  0.006154
# 3    Tuesday   January 0 days 00:14:00    840.0  0.005595
# 4  Wednesday   January 0 days 01:07:00   4020.0  0.015846

# %%
new_df['speed_kmph']=new_df['speed']*5793.6384 #converting units of speed from miles per sec to kmph for ease in calculation
# Out:
#    Trip_Id        START_DATE          END_DATE  CATEGORY            START  \
# 0        1  01-01-2016 21:11  01-01-2016 21:17  Business      Fort Pierce
# 1        2  01-02-2016 01:25  01-02-2016 01:37  Business      Fort Pierce
# 2        3  01-02-2016 20:25  01-02-2016 20:38  Business      Fort Pierce
# 3        4  01-05-2016 17:31  01-05-2016 17:45  Business      Fort Pierce
# 4        5  01-06-2016 14:42  01-06-2016 15:49  Business      Fort Pierce
# 5        6  01-06-2016 17:15  01-06-2016 17:19  Business  West Palm Beach
# 6        7  01-06-2016 17:30  01-06-2016 17:35  Business  West Palm Beach
# 7        8  01-07-2016 13:27  01-07-2016 13:33  Business             Cary
# 8        9  01-10-2016 08:05  01-10-2016 08:25  Business             Cary
# 9       10  01-10-2016 12:17  01-10-2016 12:44  Business          Jamaica
#
#               STOP          PURPOSE  MILES            start_dt  \
# 0      Fort Pierce   Meal/Entertain    5.1 2016-01-01 21:11:00
# 1      Fort Pierce              NaN    5.0 2016-01-02 01:25:00
# 2      Fort Pierce  Errand/Supplies    4.8 2016-01-02 20:25:00
# 3      Fort Pierce          Meeting    4.7 2016-01-05 17:31:00
# 4  West Palm Beach   Customer Visit   63.7 2016-01-06 14:42:00
# 5  West Palm Beach   Meal/Entertain    4.3 2016-01-06 17:15:00
# 6       Palm Beach          Meeting    7.1 2016-01-06 17:30:00
# 7             Cary          Meeting    0.8 2016-01-07 13:27:00
# 8      Morrisville          Meeting    8.3 2016-01-10 08:05:00
# 9         New York   Customer Visit   16.5 2016-01-10 12:17:00
#
#                end_dt  start_day  start_hour  start_month  d_of_week  \
# 0 2016-01-01 21:17:00          1          21            1          4
# 1 2016-01-02 01:37:00          2           1            1          5
# 2 2016-01-02 20:38:00          2          20            1          5
# 3 2016-01-05 17:45:00          5          17            1          1
# 4 2016-01-06 15:49:00          6          14            1          2
# 5 2016-01-06 17:19:00          6          17            1          2
# 6 2016-01-06 17:35:00          6          17            1          2
# 7 2016-01-07 13:33:00          7          13            1          3
# 8 2016-01-10 08:25:00         10           8            1          6
# 9 2016-01-10 12:44:00         10          12            1          6
#
#      weekday cal_month            diff  seconds     speed  speed_kmph
# 0     Friday   January 0 days 00:06:00    360.0  0.014167   82.076544
# 1   Saturday   January 0 days 00:12:00    720.0  0.006944   40.233600
# 2   Saturday   January 0 days 00:13:00    780.0  0.006154   35.653159
# 3    Tuesday   January 0 days 00:14:00    840.0  0.005595   32.416786
# 4  Wednesday   January 0 days 01:07:00   4020.0  0.015846   91.804668
# 5  Wednesday   January 0 days 00:04:00    240.0  0.017917  103.802688
# 6  Wednesday   January 0 days 00:05:00    300.0  0.023667  137.116109
# 7   Thursday   January 0 days 00:06:00    360.0  0.002222   12.874752
# 8     Sunday   January 0 days 00:20:00   1200.0  0.006917   40.072666
# 9     Sunday   January 0 days 00:27:00   1620.0  0.010185   59.009280

# %%
new_df[new_df['speed_kmph']>150].head(5)  #putting 150kmph as speed limit to check over-speeding cases
# Out:
#      Trip_Id        START_DATE          END_DATE  CATEGORY             START  \
# 121      122    2/18/2016 8:19    2/18/2016 8:27  Business  Unknown Location
# 335      336   4/28/2016 13:30   4/28/2016 13:49  Business           Raleigh
# 375      376   5/18/2016 13:00   5/18/2016 13:02  Business       Morrisville
# 751      752  09-06-2016 17:49  09-06-2016 17:49  Business  Unknown Location
# 753      754  09-11-2016 09:51  09-11-2016 09:55  Business  Unknown Location
#
#                  STOP         PURPOSE  MILES            start_dt  \
# 121  Unknown Location  Temporary Site   23.5 2016-02-18 08:19:00
# 335              Cary  Customer Visit   32.8 2016-04-28 13:30:00
# 375           Raleigh  Customer Visit    7.6 2016-05-18 13:00:00
# 751  Unknown Location             NaN   69.1 2016-09-06 17:49:00
# 753  Unknown Location             NaN    8.6 2016-09-11 09:51:00
#
#                  end_dt  start_day  start_hour  start_month  d_of_week  \
# 121 2016-02-18 08:27:00         18           8            2          3
# 335 2016-04-28 13:49:00         28          13            4          3
# 375 2016-05-18 13:02:00         18          13            5          2
# 751 2016-09-06 17:49:00          6          17            9          1
# 753 2016-09-11 09:55:00         11           9            9          6
#
#        weekday  cal_month            diff  seconds     speed  speed_kmph
# 121   Thursday   February 0 days 00:08:00    480.0  0.048958  283.646880
# 335   Thursday      April 0 days 00:19:00   1140.0  0.028772  166.694157
# 375  Wednesday        May 0 days 00:02:00    120.0  0.063333  366.930432
# 751    Tuesday  September 0 days 00:00:00      0.0       inf         inf
# 753     Sunday  September 0 days 00:04:00    240.0  0.035833  207.605376

# %%
new_df[new_df['speed_kmph']>150].shape
# Out:
# (19, 20)

# %% [markdown]
# 1.Above result also includes inf speed <br>
# 2.let's first remove speed which are shown infinite but are actually zero due to no distance travelled.

# %%
new_df.replace([np.inf , -np.inf], np.nan, inplace=True)

# %%
new_df[new_df['speed_kmph']>150].shape #to check whether inf values are converted successfully or not
# Out:
# (15, 20)

# %% [markdown]
# **4 inf values are changed to zero and also
# from above data of speed greater than 150, we can see that some anomalies are present as speed can't be more than 200kmph that too in rare cases**

# %%
#to replace with a suitable value let's calculate average speed
new_df['speed_kmph'].mean()
# Out:
# 43.142808241535754

# %%
new_df[new_df['speed_kmph']>150]
# Out:
#      Trip_Id        START_DATE          END_DATE  CATEGORY             START  \
# 121      122    2/18/2016 8:19    2/18/2016 8:27  Business  Unknown Location
# 335      336   4/28/2016 13:30   4/28/2016 13:49  Business           Raleigh
# 375      376   5/18/2016 13:00   5/18/2016 13:02  Business       Morrisville
# 753      754  09-11-2016 09:51  09-11-2016 09:55  Business  Unknown Location
# 754      755  09-11-2016 21:40  09-11-2016 21:42  Business  Unknown Location
# 762      763   9/18/2016 18:07   9/18/2016 18:11  Business  Unknown Location
# 773      774    9/27/2016 8:33    9/27/2016 8:35  Business  Unknown Location
# 781      782  10-03-2016 17:09  10-03-2016 17:12  Business  Unknown Location
# 786      787  10-04-2016 12:17  10-04-2016 12:18  Business  Unknown Location
# 788      789  10-06-2016 17:23  10-06-2016 17:40  Business        R?walpindi
# 789      790  10-06-2016 18:37  10-06-2016 18:39  Business  Unknown Location
# 791      792  10-07-2016 10:56  10-07-2016 10:59  Business  Unknown Location
# 799      800  10-08-2016 18:15  10-08-2016 18:18  Business           Karachi
# 804      805  10-12-2016 19:18  10-12-2016 19:21  Business        R?walpindi
# 933      934  11-10-2016 15:17  11-10-2016 15:22  Business     San Francisco
#
#                  STOP         PURPOSE  MILES            start_dt  \
# 121  Unknown Location  Temporary Site   23.5 2016-02-18 08:19:00
# 335              Cary  Customer Visit   32.8 2016-04-28 13:30:00
# 375           Raleigh  Customer Visit    7.6 2016-05-18 13:00:00
# 753  Unknown Location             NaN    8.6 2016-09-11 09:51:00
# 754  Unknown Location             NaN    9.8 2016-09-11 21:40:00
# 762  Unknown Location             NaN    9.4 2016-09-18 18:07:00
# 773  Unknown Location             NaN    5.8 2016-09-27 08:33:00
# 781         Islamabad             NaN   10.5 2016-10-03 17:09:00
# 786  Unknown Location             NaN   15.1 2016-10-04 12:17:00
# 788  Unknown Location             NaN  112.6 2016-10-06 17:23:00
# 789  Unknown Location             NaN   18.4 2016-10-06 18:37:00
# 791            Lahore             NaN   33.2 2016-10-07 10:56:00
# 799  Unknown Location             NaN    8.0 2016-10-08 18:15:00
# 804  Unknown Location             NaN   18.4 2016-10-12 19:18:00
# 933           Oakland  Temporary Site    9.9 2016-11-10 15:17:00
#
#                  end_dt  start_day  start_hour  start_month  d_of_week  \
# 121 2016-02-18 08:27:00         18           8            2          3
# 335 2016-04-28 13:49:00         28          13            4          3
# 375 2016-05-18 13:02:00         18          13            5          2
# 753 2016-09-11 09:55:00         11           9            9          6
# 754 2016-09-11 21:42:00         11          21            9          6
# 762 2016-09-18 18:11:00         18          18            9          6
# 773 2016-09-27 08:35:00         27           8            9          1
# 781 2016-10-03 17:12:00          3          17           10          0
# 786 2016-10-04 12:18:00          4          12           10          1
# 788 2016-10-06 17:40:00          6          17           10          3
# 789 2016-10-06 18:39:00          6          18           10          3
# 791 2016-10-07 10:59:00          7          10           10          4
# 799 2016-10-08 18:18:00          8          18           10          5
# 804 2016-10-12 19:21:00         12          19           10          2
# 933 2016-11-10 15:22:00         10          15           11          3
#
#        weekday  cal_month            diff  seconds     speed   speed_kmph
# 121   Thursday   February 0 days 00:08:00    480.0  0.048958   283.646880
# 335   Thursday      April 0 days 00:19:00   1140.0  0.028772   166.694157
# 375  Wednesday        May 0 days 00:02:00    120.0  0.063333   366.930432
# 753     Sunday  September 0 days 00:04:00    240.0  0.035833   207.605376
# 754     Sunday  September 0 days 00:02:00    120.0  0.081667   473.147136
# 762     Sunday  September 0 days 00:04:00    240.0  0.039167   226.917504
# 773    Tuesday  September 0 days 00:02:00    120.0  0.048333   280.025856
# 781     Monday    October 0 days 00:03:00    180.0  0.058333   337.962240
# 786    Tuesday    October 0 days 00:01:00     60.0  0.251667  1458.065664
# 788   Thursday    October 0 days 00:17:00   1020.0  0.110392   639.572239
# 789   Thursday    October 0 days 00:02:00    120.0  0.153333   888.357888
# 791     Friday    October 0 days 00:03:00    180.0  0.184444  1068.604416
# 799   Saturday    October 0 days 00:03:00    180.0  0.044444   257.495040
# 804  Wednesday    October 0 days 00:03:00    180.0  0.102222   592.238592
# 933   Thursday   November 0 days 00:05:00    300.0  0.033000   191.190067

# %%
for x in new_df.index:
  if new_df.loc[x, "speed_kmph"] > 150:
    new_df.loc[x, "speed_kmph"] = new_df['speed_kmph'].mean()

# %%
new_df[new_df['speed_kmph']>150]
# Out:
# Empty DataFrame
# Columns: [Trip_Id, START_DATE, END_DATE, CATEGORY, START, STOP, PURPOSE, MILES, start_dt, end_dt, start_day, start_hour, start_month, d_of_week, weekday, cal_month, diff, seconds, speed, speed_kmph]
# Index: []

# %% [markdown]
# ## 4. Category & Purpose
# #### Explore the category and the purpose of the trips through
# - Most frequent trip category
# - Most frequent trip purpose
# - Miles driven per category and purpose
# - Percent composition of business miles vs personal miles
# - time spent per category and purpose

# %% [markdown]
# **1. Most frequent trip category**

# %%
new_df.groupby(['CATEGORY'])['Trip_Id'].count()
# Out:
# CATEGORY
# Business    1078
# Personal      77
# Name: Trip_Id, dtype: int64

# %% [markdown]
# **Most trips are in the business category**

# %% [markdown]
# **2. Most frequent Purpose**

# %%
new_df.groupby(['PURPOSE'])['Trip_Id'].count().sort_values(ascending=False)
# Out:
# PURPOSE
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: Trip_Id, dtype: int64

# %% [markdown]
# **Most trips are for meetings**

# %%
#Average distance traveled for each activity
new_df.groupby(['PURPOSE'])['MILES'].mean().sort_values(ascending=False)
# Out:
# PURPOSE
# Commute            180.200000
# Customer Visit      20.688119
# Meeting             15.247594
# Charity ($)         15.100000
# Between Offices     10.944444
# Temporary Site      10.474000
# Meal/Entertain       5.698125
# Airport/Travel       5.500000
# Moving               4.550000
# Errand/Supplies      3.968750
# Name: MILES, dtype: float64

# %% [markdown]
# **Now lets try to answer some questions from this data.**
#
# **Question3**: How many miles were driven per category and purpose ?
#
# **Question4**: What is percentage of business miles vs personal?
#
# **Question5**: How much time was spend for drives per category and purpose?  - <i>for practice: you will need to create a time difference variable - answers will be shared through a notebook</i>

# %%
#Question3: How many miles were driven per category and purpose ?
new_df.groupby(['CATEGORY','PURPOSE'])['MILES'].sum().sort_values(ascending=False)
# Out:
# CATEGORY  PURPOSE
# Business  Meeting            2851.3
#           Customer Visit     2089.5
#           Meal/Entertain      911.7
#           Temporary Site      523.7
#           Errand/Supplies     508.0
#           Between Offices     197.0
# Personal  Commute             180.2
#           Moving               18.2
# Business  Airport/Travel       16.5
# Personal  Charity ($)          15.1
# Name: MILES, dtype: float64

# %%
#Question4: What is percentage of business miles vs personal?
perc=new_df.groupby(['CATEGORY'])['MILES'].sum()
perc
# Out:
# CATEGORY
# Business    11487.0
# Personal      717.7
# Name: MILES, dtype: float64

# %%
DF=perc.to_frame()           #converting above series to dataframe
DF
# Out:
#             MILES
# CATEGORY
# Business  11487.0
# Personal    717.7

# %%
DF['percent']=(DF['MILES'] / DF['MILES'].sum())*100
DF
# Out:
#             MILES    percent
# CATEGORY
# Business  11487.0  94.119479
# Personal    717.7   5.880521

# %% [markdown]
# **Business miles percentage is 94 and Personal miles percentage are 6**

# %% [markdown]
# ## Profile Report -
# Through the exercise, we discussed the various aspects the driver profile for the uberdriver data given. The insights received were-
#
# **Name and number of all the unique start and stop points**<br>
# We found the unique start and stop points for the driver. We figured out the localities the driver is active in.
#
# **Popular start and stop point**<br>
# Cary has been the most popular start and stop point
#
# **Rides with same start and stop points**<br>
# 288 such rides were found
#
# **Starting point from which most miles have been driven**<br>
# Unknown location followed by Cary
#
# **Start- stop pairs that are most travelled in terms of distance**<br>
# Morissville - Cary
#
# **busiest month in terms of number of drives and miles driven**<br>
# In terms of no of drives - December
# In terms of miles driven - October
#
# **busiest day of the week**<br>
# Friday
#
# **peak hours**<br>
# 1PM - 6PM
#
# **most frequent trip category**<br>
# Business
#
# **most frequent trip purpose**<br>
# Meeting
#
# **miles driven per category and purpose**<br>
# We figured these numbers out. Category wise Business and purpose wise meetings were leading in terms of miles driven
#
# **percent composition of business miles vs personal miles**<br>
# Business - 94%
# Personal - 6%
#
#
# ## Summary  -
# Through this exercise, we tried to check out the data analysis toolkit offered by pandas. We went to explore variables at hand, use groupby, implement datatime manipulation, explored possibility to create new features and various other operations on pandas dataframe.
# We also had a sneak peek into the upcoming week's topic of visualization.
#
# Learners are recommended to explore further on this building on the points discussed in the notebook.
# Happy Learning!
